# %% [markdown]
# <a href="https://colab.research.google.com/github/larissamazzero/RMN/blob/main/KNN/knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K Nearest Neighbours algorithm (KNN)

# %% [markdown]
# https://www.kaggle.com/code/prashant111/knn-classifier-tutorial

# %% [markdown]
# KNN é um dos algoritmos de aprendizagem supervisionada mais simples no campo de data mining e machine learning. é um algoritmo não paramétrico usado para tarefas de regressão e classificação. É um classificador **baseado no "quão similar" é um dado (vetor) do outro**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exemplo

# %% [markdown]
# https://medium.com/brasil-ai/knn-k-nearest-neighbors-1-e140c82e9c4e
